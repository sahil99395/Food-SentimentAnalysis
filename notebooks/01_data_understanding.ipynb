# %%
import pandas as pd

df = pd.read_csv("../data/zomato_reviews.csv")

df.head()
# Out:
#    Unnamed: 0  rating                                             review
# 0           0       5                                               nice
# 1           1       5  best biryani , so supportive staff of outlet ,...
# 2           2       4     delivery boy was very decent and supportive.👌👍
# 3           3       1  worst biryani i have tasted in my life, half o...
# 4           4       5  all food is good and tasty . will order again ...

# %%
df.shape
# Out:
# (5479, 3)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rating', 'review'], dtype='str')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# rating        0
# review        1
# dtype: int64

# %%
df["review"].sample(10)
# Out:
# 5365    Waste of money to buy from this restaurant tas...
# 3231                           kulcha should be cook well
# 2086                      this is not the cake i ordered
# 2744     really bad taste and mutton is not proper cooked
# 1484                              Bhot late delivery huva
# 169                       size of both item is very less
# 4033    Enjoyed the dinner from Mysore Express Restaur...
# 2838                                                nice
# 2558    Quantity of the food is very less. I ordered f...
# 1778                                               Refund
# Name: review, dtype: str

# %%
def sentiment_label(rating):
    if rating >= 4:
        return "Positive"
    elif rating == 3:
        return "Neutral"
    else:
        return "Negative"

# %%
df["sentiment"] = df["rating"].apply(sentiment_label)

# %%
df.head()
# Out:
#    Unnamed: 0  rating                                             review  \
# 0           0       5                                               nice
# 1           1       5  best biryani , so supportive staff of outlet ,...
# 2           2       4     delivery boy was very decent and supportive.👌👍
# 3           3       1  worst biryani i have tasted in my life, half o...
# 4           4       5  all food is good and tasty . will order again ...
#
#   sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Negative
# 4  Positive
